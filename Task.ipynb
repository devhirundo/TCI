# %% [markdown]
# [Tensor4all TCI Github Page (preview)](https://github.com/tensor4all/TensorCrossInterpolation.jl)
# <br>
# [Tensor4all TCI Github Page (manual)](https://tensor4all.org/TensorCrossInterpolation.jl/dev/)

# %%
# pkg import test
import TensorCrossInterpolation as TCI

# %%
# Example Code in manual
f(v) = 1/(1 + v' * v)
localdims = fill(10, 5)    # There are 5 tensor indices, each with values 1...10
tolerance = 1e-8
tci, ranks, errors = TCI.crossinterpolate2(Float64, f, localdims; tolerance=tolerance)
println(tci)
println(ranks)
println(errors)
# Out:
# TensorCrossInterpolation.TensorCI2{Float64} with rank 11
# [11, 11, 11]
# [2.0169632000723285e-9, 1.9111313748018586e-9, 1.9111313748018586e-9]

# %% [markdown]
# Implement TCI for Given Function :
# $$
# \begin{split}
# f(j;kl) &= \cos{(2 \pi \frac{jk}{N})} \cdot \sin{(2 \pi \frac{jl}{N})} \cdot e^{-\frac{j}{N}} \\ &+ \sin{(2 \pi \frac{jk}{N})} \cdot \cos(2 \pi \frac{jl}{N}) \cdot e^{-\frac{j^2}{N^2}}
# \end{split}
# $$

# %% [markdown]
# <font size = 5> **Task 1** </font> <br>
# Show that for given $j$, $\tilde{f}_{j}(kl)$ can be well approximated by TCI.

# %%
# pkg import
import TensorCrossInterpolation as TCI
using Plots

#Exact Case
j::Int = 1
N::Int = 100

function f(v)
    k = v[1]
    l = v[2]
    term1 = cos(2*π*(j*k/N)) * sin(2*π*(j*l/N))* exp(-j/N)
    term2 = sin(2*π*(j*k/N)) * cos(2*π*(j*l/N))* exp(-j^2/N^2)
    return term1 + term2
end

originalMatrix = [f((i,j)) for i in 1:N, j in 1:N]
vis = heatmap(originalMatrix, title="Original Matrix", aspect_ratio=:equal, color=:viridis)

localdims = fill(N, 2) # N lattices for 2 variable
tolerance = 1e-8 #target error
tci, ranks, errors = TCI.crossinterpolate2(Float64, f, localdims; tolerance=tolerance)

println(ranks)
println(errors)
println(tci) #maybe I can access using its property
println(dump(tci))

plot(vis,size=(800, 800))
# Out:
# [2, 2, 2]
# [4.441336209915677e-16, 4.441336209915677e-16, 4.441336209915677e-16]
# TensorCrossInterpolation.TensorCI2{Float64} with rank 2
# TensorCrossInterpolation.TensorCI2{Float64} with rank 2 (function of type TensorCrossInterpolation.TensorCI2{Float64})
#   Iset: Array{Vector{Vector{Int64}}}((2,))
#     1: Array{Vector{Int64}}((1,))
#       1: Array{Int64}((0,)) Int64[]
#     2: Array{Vector{Int64}}((2,))
#       1: Array{Int64}((1,)) [25]
#       2: Array{Int64}((1,)) [50]
#   Jset: Array{Vector{Vector{Int64}}}((2,))
#     1: Array{Vector{Int64}}((2,))
#       1: Array{Int64}((1,)) [50]
#       2: Array{Int64}((1,)) [25]
#     2: Array{Vector{Int64}}((1,))
#       1: Array{Int64}((0,)) Int64[]
#   localdims: Array{Int64}((2,)) [100, 100]
#   sitetensors: Array{Array{Float64, 3}}((2,))
#     1: Array{Float64}((1, 100, 2)) [0.0627905195293135 0.1253332335643044 … -0.06279051952931314 -1.224646799147353e-16;;; -0.9980267284282716 -0.9921147013144779 … -0.9980267284282716 -1.0]
#     2: Array{Float64}((2, 100, 1)) [0.9979269307453961 0.9920154948047546 … 0.9979269307453961 0.9999000049998333; -0.06216574342102047 -0.12408614705358496 … 0.06216574342102062 3.6494470603850443e-16;;;]
#   pivoterrors: Array{Float64}((3,)) [0.9999000049998333, 0.9900498337491681, 0.0]
#   bonderrors: Array{Float64}((1,)) [0.0]
#   maxsamplevalue: Float64 0.9999000049998333
#   Iset_history: Array{Vector{Vector{Vector{Int64}}}}((6,))
#     1: Array{Vector{Vector{Int64}}}((2,))
#       1: Array{Vector{Int64}}((1,))
#         1: Array{Int64}((0,)) Int64[]
#       2: Array{Vector{Int64}}((1,))
#         1: Array{Int64}((1,)) [1]
#     2: Array{Vector{Vector{Int64}}}((2,))
#       1: Array{Vector{Int64}}((1,))
#         1: Array{Int64}((0,)) Int64[]
#       2: Array{Vector{Int64}}((2,))
#         1: Array{Int64}((1,)) [25]
#         2: Array{Int64}((1,)) [50]
#     3: Array{Vector{Vector{Int64}}}((2,))
#       1: Array{Vector{Int64}}((1,))
#         1: Array{Int64}((0,)) Int64[]
#       2: Array{Vector{Int64}}((2,))
#         1: Array{Int64}((1,)) [25]
#         2: Array{Int64}((1,)) [50]
#     4: Array{Vector{Vector{Int64}}}((2,))
#       1: Array{Vector{Int64}}((1,))
#         1: Array{Int64}((0,)) Int64[]
#       2: Array{Vector{Int64}}((2,))
#         1: Array{Int64}((1,)) [25]
#         2: Array{Int64}((1,)) [50]
#     5: Array{Vector{Vector{Int64}}}((2,))
#       1: Array{Vector{Int64}}((1,))
#         1: Array{Int64}((0,)) Int64[]
#       2: Array{Vector{Int64}}((2,))
#         1: Array{Int64}((1,)) [25]
#         2: Array{Int64}((1,)) [50]
#     6: Array{Vector{Vector{Int64}}}((2,))
#       1: Array{Vector{Int64}}((1,))
#         1: Array{Int64}((0,)) Int64[]
#       2: Array{Vector{Int64}}((2,))
#         1: Array{Int64}((1,)) [25]
#         2: Array{Int64}((1,)) [50]
#   Jset_history: Array{Vector{Vector{Vector{Int64}}}}((6,))
#     1: Array{Vector{Vector{Int64}}}((2,))
#       1: Array{Vector{Int64}}((1,))
#         1: Array{Int64}((1,)) [1]
#       2: Array{Vector{Int64}}((1,))
#         1: Array{Int64}((0,)) Int64[]
#     2: Array{Vector{Vector{Int64}}}((2,))
#       1: Array{Vector{Int64}}((2,))
#         1: Array{Int64}((1,)) [50]
#         2: Array{Int64}((1,)) [25]
#       2: Array{Vector{Int64}}((1,))
#         1: Array{Int64}((0,)) Int64[]
#     3: Array{Vector{Vector{Int64}}}((2,))
#       1: Array{Vector{Int64}}((2,))
#         1: Array{Int64}((1,)) [50]
#         2: Array{Int64}((1,)) [25]
#       2: Array{Vector{Int64}}((1,))
#         1: Array{Int64}((0,)) Int64[]
#     4: Array{Vector{Vector{Int64}}}((2,))
#       1: Array{Vector{Int64}}((2,))
#         1: Array{Int64}((1,)) [50]
#         2: Array{Int64}((1,)) [25]
#       2: Array{Vector{Int64}}((1,))
#         1: Array{Int64}((0,)) Int64[]
#     5: Array{Vector{Vector{Int64}}}((2,))
#       1: Array{Vector{Int64}}((2,))
#         1: Array{Int64}((1,)) [50]
#         2: Array{Int64}((1,)) [25]
#       2: Array{Vector{Int64}}((1,))
#         1: Array{Int64}((0,)) Int64[]
#     6: Array{Vector{Vector{Int64}}}((2,))
#       1: Array{Vector{Int64}}((2,))
#         1: Array{Int64}((1,)) [50]
#         2: Array{Int64}((1,)) [25]
#       2: Array{Vector{Int64}}((1,))
#         1: Array{Int64}((0,)) Int64[]
# nothing

# %% [markdown]
# **Why does the matrix has rank 2?** <br>
# <img src="Image/Rank2.jpg" alt="rank2" width=800>

# %% [markdown]
# <font size = 5> **Task 2** </font> <br>
# For given $l$, $\tilde{g}_{l}(j,k)$ can be well approximated by TCI.

# %%
# pkg import
import TensorCrossInterpolation as TCI
using Plots

#Exact Case
l::Int = 1
N::Int = 100

function f(v)
    j = v[1]
    k = v[2]
    term1 = cos(2*π*(j*k/N)) * sin(2*π*(j*l/N))* exp(-j/N)
    term2 = cos(2*π*(j*k/N)) * sin(2*π*(j*l/N))* exp(-j^2/N^2)
    return term1 + term2
end

originalMatrix = [f((i,j)) for i in 1:N, j in 1:N]
vis = heatmap(originalMatrix, title="Original Matrix", aspect_ratio=:equal, color=:viridis)

localdims = fill(N, 2) # N lattices for 2 variable
tolerance = 1e-8 #target error
tci, ranks, errors = TCI.crossinterpolate2(Float64, f, localdims; tolerance=tolerance)
println(tci)
println(ranks)
println(errors)

plot(vis,size=(800, 800))
# Out:
# TensorCrossInterpolation.TensorCI2{Float64} with rank 49
# [49, 49, 49]
# [1.1569208203310336e-13, 1.1569208203310336e-13, 1.1569208203310336e-13]

# %% [markdown]
# **Why the matrix has half-rank of original matirx?** <br>
# <img src="Image/half_rank.jpg" alt="rank2" width="400">

# %% [markdown]
# <font size = 5> **For further step...** </font> <br>
# Search the property of variable 'TCI' in **TensorCrossInterpolation.jl** with 'dump' function

# %% [markdown]
# <font size = 5> **Task 3** </font> <br>
# Can we perform MC-TCI combined integral?
